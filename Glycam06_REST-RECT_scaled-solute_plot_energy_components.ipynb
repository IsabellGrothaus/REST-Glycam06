# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import panedr

# %%
df1 = panedr.edr_to_df("00_ener.edr") #lambda = 1
df2 = panedr.edr_to_df("09_ener.edr") #lambda = 0.5

# %%
df1
# Out:
#               Time        Bond       Angle  Proper Dih.  Improper Dih.  \
# 0.0            0.0  366.193298  733.785950  -117.086151       8.072813
# 8.0            8.0  326.280548  796.169434  -123.640831      10.088647
# 16.0          16.0  321.539124  777.551270  -119.954178      11.010641
# 24.0          24.0  378.920563  701.560974  -152.348892      12.040340
# 32.0          32.0  366.000977  654.625610  -116.498642      15.372672
# ...            ...         ...         ...          ...            ...
# 664824.0  664824.0  390.528442  781.994141  -154.782288      10.586633
# 664832.0  664832.0  388.166351  823.179260  -165.867645       8.328107
# 664840.0  664840.0  331.078400  720.650391  -126.179169       8.840327
# 664848.0  664848.0  328.029114  713.220703  -134.565414      11.733564
# 664856.0  664856.0  343.852509  735.330200  -105.571075       7.638351
#
#                LJ-14   Coulomb-14       LJ (SR)  Coulomb (SR)  Coul. recip.  \
# ...

# %%
plt.scatter(df1.Time,df1["Proper Dih."], label="lambda=1")
plt.scatter(df2.Time,df2["Proper Dih."], label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.Time,df1["LJ-14"], label="lambda=1")
plt.scatter(df2.Time,df2["LJ-14"], label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.Time,df1["Coulomb-14"], label="lambda=1")
plt.scatter(df2.Time,df2["Coulomb-14"], label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.Time,df1["Coul. recip."], label="lambda=1")
plt.scatter(df2.Time,df2["Coul. recip."], label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.Time,df1["LJ (SR)"], label="lambda=1")
plt.scatter(df2.Time,df2["LJ (SR)"], label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.Time,df1["Coulomb (SR)"], label="lambda=1")
plt.scatter(df2.Time,df2["Coulomb (SR)"], label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1["Proper Dih."],df2["Proper Dih."])

# %%
plt.scatter(df1["LJ-14"],df2["LJ-14"])

# %%
plt.scatter(df1["Coulomb-14"],df2["Coulomb-14"])

# %%
plt.scatter(df1["Coul. recip."],df2["Coul. recip."])

# %%
plt.scatter(df1["LJ (SR)"],df2["LJ (SR)"])

# %%
plt.scatter(df1["Coulomb (SR)"],df2["Coulomb (SR)"])
