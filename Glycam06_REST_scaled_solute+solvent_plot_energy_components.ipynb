# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("0_potential.xvg", delim_whitespace=True, names = ["time", "dihedrals", "improper", "LJ14", "coulomb14", "LJSR", "coulombSR"]) #lambda = 1
df2 = pd.read_csv("9_potential.xvg", delim_whitespace=True, names = ["time", "dihedrals", "improper", "LJ14", "coulomb14", "LJSR", "coulombSR"]) #lambda = 0.5

# %%
plt.scatter(df1.time,df1.dihedrals, label="lambda=1")
plt.scatter(df2.time,df2.dihedrals, label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.time,df1.improper, label="lambda=1")
plt.scatter(df2.time,df2.improper, label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.time,df1.improper, label="lambda=1")
plt.scatter(df2.time,df2.improper, label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.time,df1.LJ14, label="lambda=1")
plt.scatter(df2.time,df2.LJ14, label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.time,df1.coulomb14, label="lambda=1")
plt.scatter(df2.time,df2.coulomb14, label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.time,df1.LJSR, label="lambda=1")
plt.scatter(df2.time,df2.LJSR, label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.time,df1.coulombSR, label="lambda=1")
plt.scatter(df2.time,df2.coulombSR, label="lambda=0.5")
plt.legend()

# %%
plt.scatter(df1.dihedrals,df2.dihedrals)

# %%
plt.scatter(df1.improper,df2.improper)

# %%
plt.scatter(df1.LJ14,df2.LJ14)

# %%
plt.scatter(df1.coulomb14,df2.coulomb14)

# %%
plt.scatter(df1.LJSR,df2.LJSR)

# %%
plt.scatter(df1.coulombSR,df2.coulombSR)
